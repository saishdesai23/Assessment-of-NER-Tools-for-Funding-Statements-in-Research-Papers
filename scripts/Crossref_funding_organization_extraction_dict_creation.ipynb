# %%
import csv
import xml
import xml.etree.ElementTree as ET
from string import ascii_lowercase as alph

# %%
tree = ET.parse("./open_funder_registry-master/registry.rdf")
root = tree.getroot()

# tips at https://docs.python.org/3/library/xml.etree.elementtree.html

# %%
for x in root[0:4]:
    print(x)
    
# -> concepts start at position 2. before that it's header info
# Out:
# <Element '{http://data.crossref.org/fundingdata/terms}registry' at 0x00000209097E01D0>
# <Element '{http://www.w3.org/2004/02/skos/core#}ConceptScheme' at 0x00000209097E03B0>
# <Element '{http://www.w3.org/2004/02/skos/core#}Concept' at 0x000002090AAE6450>
# <Element '{http://www.w3.org/2004/02/skos/core#}Concept' at 0x000002090AAEC720>

# %%
print(len(root))
# Out:
# 31553

# %%
root[31552]
# -> last organization
# Out:
# <Element '{http://www.w3.org/2004/02/skos/core#}Concept' at 0x0000020920CDDE00>

# %%
# open the file in the write mode

with open('funders_extracted_crossref.csv', 'w',encoding='utf-8',newline='') as file:
    
    writer = csv.writer(file)
    header_row = ['DOI','Funding body type','Region','Country','Funding Body Sub Type', 
                  'Names (first one pref., others alternative)']
    
    writer.writerow(header_row)

    for orga in range(2,31552):

        row = []
        names = []
        
        # DOI (is at position zero of the list of values for the main attribute of every organization)
        row.append(list(root[orga].attrib.values())[0])
        
        # iterate through entries in each organization and check whether the tag is interesting
        for entry in root[orga]:

            #print(entry)
            if entry.tag == '{http://www.w3.org/2008/05/skos-xl#}prefLabel' or entry.tag == '{http://www.w3.org/2008/05/skos-xl#}altLabel':
                # -> label found
                # the name (first one found is preferred label, others are alternative names)
                names.append(entry[0][0].text)

            if entry.tag == '{http://data.crossref.org/fundingdata/xml/schema/grant/grant-1.2/}fundingBodyType':
                # -> funding orga type found
                row.append(entry.text)

            if entry.tag == '{http://data.crossref.org/fundingdata/xml/schema/grant/grant-1.2/}region':
                # -> region
                row.append(entry.text)

            if entry.tag == '{https://none.schema.org/}address':
                # -> country
                row.append(entry[0][0].text)

            if entry.tag == '{http://data.crossref.org/fundingdata/xml/schema/grant/grant-1.2/}fundingBodySubType':
                # -> funding body sub type
                row.append(entry.text)

        # organization names go last columns in csv file since their number is open-end
        row.extend(names)

        # write row to the csv file
        writer.writerow(row)

# note: when opening .csv with Excel -> convert data to columns with comma "," as separator
# also Excel may display foreign characters as gibberish, e.g. Chinese characters
# don't worry file is fine and Python works out as long as it's opened with utf-8 encoding

# %%
## create dictionary for sorted searching of orga, names

# create empty dict with list for every character in alphabet, one "other" label for non-standard first characters (e.g. Chinese names)
orga_dict = {}
for c in alph:
    orga_dict[c] = []
    if c=="z":
        orga_dict['other'] = []

for orga in range(2,31552):
    names = []

    # iterate through entries in each organization and check whether the tag is interesting
    for entry in root[orga]:

        #print(entry)
        if entry.tag == '{http://www.w3.org/2008/05/skos-xl#}prefLabel' or entry.tag == '{http://www.w3.org/2008/05/skos-xl#}altLabel':

            orga_name = entry[0][0].text.lower()
            #print(orga_name)
            #print(orga_name[0])
            if orga_name[0] in alph:
                orga_dict[orga_name[0]] == orga_dict[orga_name[0]].append(orga_name)
            else:
                orga_dict['other'].append(orga_name)

w = csv.writer(open("crossref_organizations_sorted_dict.csv", "w", encoding='utf-8', newline=''), delimiter='|')
for letter,orgs in orga_dict.items():
    w.writerow([letter,list(orgs)])

orga_dict
# Out:
# {'a': ['administración de alimentos y medicamentos de los estados unidos',
#   "american parkinson's disease foundation",
#   'apda',
#   'american diabetes association',
#   'asociación americana de la diabetes',
#   'ada',
#   'amgen foundation',
#   'amgen foundation, inc.',
#   'amgen foundation inc',
#   'american association for cancer research',
#   'american association for cancer research, inc.',
#   'american association for cancer research inc',
#   'aacr',
#   'aetna foundation',
#   'aetna foundation, inc.',
#   'aetna foundation inc',
#   'abbott fund',
#   'abbott',
#   'annenberg foundation',
#   'american cancer society',
#   'american cancer society, inc.',
#   'acs, inc.',
#   'american cancer society inc.',
#   'acs',
#   'autism speaks',
#   'autism speaks inc.',
#   'autism speaks inc',
#   'autism speaks, inc.',
#   'as',
#   'anesthesia patient safety foundation',
#   'apsf',
#   'administración de recursos y servicios de salud',
#   'administration des ressources et des services de santé',
#   'administração de recursos e serviços de saúde',
#   'advanced cyberinfrastructure',
#   'agency for healthcare research and quality',
#   'agency for healthcare research & quality',
#   'agencia de investigación y calidad sanitaria',
#   'ahrq',
#   'agencia de protección ambiental de estados unidos',
#   'avon foundation for women',
#   'avon foundation',
#   'afw',
#   'atmospheric and geospace sciences',
#   'ags',
#   'antarctic sciences',
#   'ant',
#   'arctic sciences',
#   'arc',
#   'astronomical sciences',
#   'ast',
#   'antarctic infrastructure and logistics',
#   'ail',
#   'air force office of scientific research',
#   'af office of scientific research',
#   'afosr',
#   'army research office',
#   'aro',
#   'arts endowment',
#   'agency for international development',
#   'american library association',
#   'ala american library association',
#   'ala',
#   'administración nacional de archivos y registros',
#   'american society for engineering education',
#   'asee',
#   'andrew w. mellon foundation',
#   'andrew w mellon foundation',
#   'awmf',
#   'alfred p. sloan foundation',
#   'apsf',
#   'aspen institute',
#   'annie e. casey foundation',
#   'annie e casey foundation',
#   'annie e casey foundation inc',
#   'annie e casey foundation inc/the',
#   'aecf',
#   'abell-hanger foundation',
#   'abell hanger foundation',
#   'abell-hanger foundation inc',
#   'ahf',
#   'aflac',
#   'aflac incorporated',
#   'american family life assurance company of columbus',
#   'aflac inc.',
#   'agilent foundation',
#   'alcoa foundation',
#   'albert and margaret alkek foundation',
#   'albert & margaret alkek foundation',
#   'akron community foundation',
#   'akron community fdn.',
#   'acf',
#   'akron general development foundation',
#   'agdf',
#   'alcon foundation',
#   'alcon foundation inc.',
#   'alcon foundation inc',
#   'alliance for cancer gene therapy',
#   'alliance for cancer gene therapy, inc.',
#   'alliance for cancer gene therapy inc',
#   'alliance for cancer gene therapy (acgt) foundation',
#   'acgt',
#   'alliant energy foundation',
#   "alzheimer's association",
#   "alzheimer's disease and related disorders association, inc.",
#   "alzheimer's disease and related disorders association inc",
#   "alzheimer's disease & related disorders association inc",
#   'aa',
#   'american association for the advancement of science',
#   'aaas',
#   'american association of orthopaedic surgeons',
#   'aaos',
#   'american college of rheumatology research and education foundation',
#   'acr',
#   'american committee for the weizmann institute of science',
#   'acwis',
#   'american council of learned societies',
#   'acls',
#   'american diabetes association research foundation',
#   'american diabetes association (ada) research foundation',
#   'ada research foundation',
#   'american diabetes association research foundation, inc.',
#   'adarf',
#   'arthritis national research foundation',
#   'arthritis natl research fdn',
#   'anrf',
#   'american federation for aging research',
#   'american federation for aging research, inc.',
#   'american federation for aging research inc',
#   'afar',
#   'american health assistance foundation',
#   'ahaf',
#   'american heart association',
#   'american heart association, inc.',
#   'american heart assoc.',
#   'american heart association, inc',
#   'american heart assn.',
#   'american heart assn',
#   'american heart association inc',
#   'aha',
#   'american institute for cancer research',
#   'american institute for cancer research, inc.',
#   'aicr',
#   'als association',
#   'amyotrophic lateral sclerosis association',
#   'amyotrophic lateral sclerosis assn.',
#   'als assoc.',
#   'amyotrophic lateral sclerosis assn',
#   'alsa',
#   'argosy foundation',
#   'arizona community foundation',
#   'arizona community foundation, inc.',
#   'az community foundation',
#   'arizona community foundation inc',
#   'acf',
#   'arkansas community foundation',
#   'arcf',
#   'arthritis foundation',
#   'arthritis foundation inc',
#   'arthritis foundation, inc.',
#   'af',
#   'arthur foundation',
#   'asia foundation',
#   'assisi foundation of memphis',
#   'assisi foundation of memphis, inc.',
#   'assisi foundation',
#   'assisi foundation of memphis inc',
#   'afm',
#   'atherton family foundation',
#   'austin community foundation',
#   'acf',
#   'arnold and mabel beckman foundation',
#   'arnold & mabel beckman foundation',
#   'arnold & mabel beckman foundation inc',
#   'ambf',
#   'amon g. carter foundation',
#   'amon g carter foundation',
#   'agcf',
#   'arthur vining davis foundations',
#   'avdf',
#   'amfar, the foundation for aids research',
#   'amfar',
#   'amfar the foundation for aids research',
#   'ambrose monell foundation',
#   'ambrose monell foundation/the',
#   'amf',
#   'amelia peabody charitable fund',
#   'amelia peabody charitable fund trs',
#   'apcf',
#   'abbott laboratories',
#   'abbott',
#   'abbott u.s.',
#   'alexander and margaret stewart trust',
#   'alexander & margaret stewart trust',
#   'ann and bill swindells charitable trust',
#   'ann & bill swindells charitable trust',
#   'andy warhol foundation for the visual arts',
#   'andy warhol foundation for the visual arts inc.',
#   'andy warhol foundation',
#   'awfva',
#   'acacia foundation',
#   'american society of hematology',
#   'american society of hematology inc',
#   'american society of hematology, inc.',
#   'american society of hematology inc.',
#   'ash',
#   'american liver foundation',
#   'american liver foundation national',
#   'alf',
#   'abney foundation',
#   'af',
#   'accelerate brain cancer cure',
#   'accelerate brain cancer cure, inc.',
#   'accelerate brain cancer cure inc',
#   'abc2',
#   'achelis foundation',
#   'ada foundation',
#   'american dental association foundation',
#   'adaf',
#   'aec trust',
#   'abmrf/the foundation for alcohol research',
#   'ambrf/foundation for alcohol research',
#   "alex's lemonade stand foundation for childhood cancer",
#   "alex's lemonade stand foundation",
#   "alex's lemonade stand",
#   "alex's lemonade",
#   'alsf',
#   'alpha-1 foundation',
#   'alpha-1 foundation, inc.',
#   'alpha-1 foundation inc',
#   'a1f',
#   "alzheimer's disease research foundation",
#   'amazon conservation association',
#   'aca',
#   'american academy of family physicians foundation',
#   'aafp foundation',
#   'american brain tumor association',
#   'asociación estadounidense de tumores cerebrales',
#   'asociación americana de tumores cerebrales',
#   'abta',
#   'american epilepsy society',
#   'american epilepsy society inc',
#   'american epilepsy society, inc.',
#   'aes',
#   'american foundation for suicide prevention',
#   'afsp',
#   'american friends of laniado hospital',
#   'american institute of indian studies',
#   'aiis',
#   'american kennel club canine health foundation',
#   'akc canine health foundation',
#   'american kennel club canine health foundation, inc.',
#   'american kennel club canine health foundation, inc',
#   'akc canine health foundation, inc.',
#   'akc canine health foundation inc',
#   'akc chf',
#   'american medical association foundation',
#   'ama foundation',
#   'amaf',
#   'american orthopaedic foot and ankle society',
#   'american orthopaedic foot & ankle society',
#   'aofas',
#   'american philosophical society',
#   'am phil society',
#   'amphilsoc',
#   'aps',
#   'american psychiatric publishing',
#   'american psychiatric publishing, inc.',
#   'appi',
#   'american society of nephrology',
#   'am soc nephrology',
#   'asn',
#   'american thoracic society',
#   'american thoracic society, inc.',
#   'american thoracic society inc',
#   'american thoracic',
#   'american thoracic society inc.',
#   'ats',
#   'american urological association foundation',
#   'aua foundation',
#   'american-scandinavian foundation',
#   'american scandinavian foundation',
#   'asf + scan house',
#   'asf + scandinavia house',
#   'asf',
#   'ann arbor area community foundation',
#   'ann arbor area cf',
#   'aaacf',
#   'ao north america',
#   'ao north america, inc.',
#   'ao north america inc',
#   'aona inc.',
#   'ao north america inc.',
#   'aona',
#   'ao na',
#   'asian cultural council',
#   'asian cultural council, inc.',
#   'asian cultural council inc',
#   'ajāu màhnfa hipwúi',
#   'acc',
#   'andrea and charles bronfman philanthropies',
#   'andrea and charles bronfman philanthropies inc.',
#   'acbp',
#   'a. e. finley foundation',
#   'a. e. finley foundation, inc.',
#   'a e finley foundation inc',
#   'ae finley foundation',
#   'a.e. finley foundation',
#   'a.e. finley foundation, inc.',
#   "alzheimer's research foundation, fisher center",
#   'arnold p. gold foundation',
#   'arnold p gold foundation',
#   'apgf',
#   'a.l. mailman family foundation',
#   'armstrong mcdonald foundation',
#   'alianza de esclerosis tuberosa',
#   "a. lindsay and olive b. o'connor foundation",
#   "a. lindsay & olive b. o'connor foundation",
#   "a. lindsay & olive b. o'connor foundation, inc.",
#   'ara parseghian medical research foundation',
#   'ara parseghian research medical foundation',
#   'apmrf',
#   'alice kleberg reynolds foundation',
#   'alice kleberg reynolds meyer foundation',
#   'akr foundation',
#   'akr',
#   'adolph and ruth schnurmacher foundation',
#   'ars foundation',
#   'adolph and ruth schnurmacher foundation, inc.',
#   'advanced medical research foundation',
#   'amrf',
#   'alden trust',
#   'american academy of dermatology',
#   'american academy of dermatology, inc.',
#   'american academy of dermatology inc.',
#   'american academy of dermatology inc',
#   'american academy of dermatology association',
#   'aad',
#   'american breast cancer foundation',
#   'abcf',
#   'american councils',
#   'american councils for international education',
#   'ac',
#   'american floral endowment',
#   'afe',
#   'american hotel and lodging educational foundation',
#   'american hotel & lodging educational foundation',
#   'american hotel and lodging educational foundation, inc.',
#   'ah&lef',
#   'ahlef',
#   'american lung association-southeast region',
#   'american lung association in california',
#   'american lung association in florida',
#   'american nurses association',
#   'ana',
#   'american physical therapy association',
#   'apta',
#   'american psychiatric foundation',
#   'apf',
#   'american psychological foundation',
#   'american psychological foundation, inc.',
#   'american psychological foundation inc.',
#   'american psychological foundation inc',
#   'apf',
#   'american skin association',
#   'american skin association, inc.',
#   'american skin association inc',
#   'asa',
#   'american society for gastrointestinal endoscopy',
#   'asge gi endoscopy',
#   'asge',
#   'ashp research and education foundation',
#   'ashp foundation',
#   'ashp research & education foundation',
#   'ashp ref',
#   'american society of tropical medicine and hygiene',
#   'american society of tropical medicine & hygiene',
#   'astmh',
#   'american tinnitus association',
#   'americantinnitusassn',
#   'ata',
#   'angelman syndrome foundation',
#   'angelman syndrome foundation, inc.',
#   'asf incorporated',
#   'angelman syndrome foundation inc',
#   'angelman syndrome foundation inc.',
#   'angelmansyndromefdn',
#   'asf',
#   'arizona kidney foundation',
#   'akf',
#   'arkansas humanities council',
#   'arkansas humanities council inc',
#   'arkansas humanities council inc.',
#   'arkansas humanities council, inc.',
#   'ar humanities',
#   'ahc',
#   'arkay foundation',
#   'arkay foundation inc',
#   'arkay foundation, inc.',
#   'arkay foundation inc.',
#   'armstrong foundation',
#   'asda foundation',
#   'american society for radiation oncology',
#   'astro',
#   "a-t children's project",
#   'a-t childrens project',
#   "ataxia telangiectasia children's project",
#   "at children's project",
#   "ataxia telangiectasia children's project, inc",
#   "ataxia telangiectasia children's project, inc.",
#   'atcp',
#   "atlanta women's foundation",
#   'awf',
#   'ardmore foundation',
#   'ardmore foundation, inc.',
#   'ags foundation for health in aging',
#   'a.p. giannini foundation',
#   'a p giannini foundation',
#   'ap giannini foundation',
#   'a. p. giannini foundation',
#   'apgf',
#   'arthur l. and elaine v. johnson foundation',
#   'arthur l. & elaine v. johnson foundation',
#   'american association of blood banks',
#   'amgen',
#   'amgen inc.',
#   'applied molecular genetics inc.',
#   'amgen inc',
#   'aaep foundation',
#   'aicardi syndrome foundation',
#   'aid for cancer research',
#   'acr',
#   'aids healthcare foundation',
#   'aids healthcare foundation, inc.',
#   'aids healthcare',
#   'ahf',
#   'aircast foundation',
#   'ajs foundation for metabolic diseases',
#   'alaska humanities forum',
#   'akhf',
#   'alpha omega foundation',
#   'alpha omega foundation, inc.',
#   'alpha omicron pi foundation',
#   'aoii foundation',
#   'als hope foundation',
#   'alshf',
#   'alternatives research and development foundation',
#   'alternatives research & development foundation',
#   'alternatives for research and development foundation',
#   'ardf',
#   "alzheimer's drug discovery foundation",
#   "alzheimer's drug discovery foundation, llc",
#   'alzheimers drug discovery foundation',
#   'addf',
#   'american academy of allergy asthma and immunology',
#   'american academy of allergy, asthma & immunology',
#   'american academy of allergy, asthma, and immunology',
#   'american academy of allergy, asthma and immunology',
#   'aaaai',
#   'american association for clinical chemistry',
#   'american assn for clinical chemistry',
#   'american association for clinical chemistry inc',
#   'american association for clinical chemistry inc.',
#   'aacc',
#   'american association of endodontists foundation',
#   'aae foundation',
#   'aae foundation for endodontics',
#   'aaef',
#   'american association of immunologists',
#   'american association of immunologists, inc.',
#   'american association of immunologists inc',
#   'aai',
#   'american association of plastic surgeons',
#   'aaps society',
#   'aaps',
#   'american autoimmune related diseases association',
#   'american autoimmune related diseases association, inc.',
#   'aarda',
#   'american bar foundation',
#   'abf',
#   'american college of obstetricians and gynecologists',
#   'acog',
#   'american cyronics society',
#   'acs',
#   "american dental hygienists' association",
#   'american dental hygienists association',
#   'american dental hygienists association inc',
#   'adha',
#   'american dietetic association foundation',
#   'adaf',
#   'american fibromyalgia syndrome association',
#   'american fibromyalgia syndrome association inc',
#   'american fibromyalgia syndrome association, inc.',
#   'afsa',
#   'american fidelity foundation',
#   'af foundation',
#   'american geriatrics society',
#   'american geriatrics society inc',
#   'ags',
#   'american hearing research foundation',
#   'american hearing rf',
#   'ahrf',
#   'american historical association',
#   'aha',
#   'american institutes for research',
#   'air',
#   'american lung association in alabama',
#   'alaa',
#   'american lung association of indiana',
#   'american lung association in north carolina',
#   'american lung association',
#   'ala',
#   'american lung association of the northeast',
#   'american lung association of virginia',
#   'american orchid society',
#   'american orchid society inc',
#   'american orchid society, inc.',
#   'american orchid society inc.',
#   'aos',
#   'american osteopathic association',
#   'aoa',
#   'american otological society',
#   'american otological society, inc.',
#   'aos, inc.',
#   'american otological society, inc',
#   'american otological society inc',
#   'aos',
#   'american pharmacists association foundation',
#   'apha foundation',
#   'american pharmacists association (apha) foundation',
#   'apaf',
#   'american physicians fellowship for medicine in israel',
#   'apf',
#   'american porphyria foundation',
#   'apf',
#   'american public power association',
#   'american public power assoc',
#   'american public power assoc.',
#   'appa',
#   'american sleep medicine foundation',
#   'asmf',
#   'asis foundation',
#   'asis foundation inc',
#   'asis foundation, inc.',
#   'asis foundation inc.',
#   'american society for laser medicine and surgery',
#   'american society for laser medicine and surgery, inc.',
#   'american society for laser medicine & surgery, inc.',
#   'american society for laser medicine & surgery',
#   'american society for laser medicine and surgery inc',
#   'american society for laser medicine & surgery inc',
#   'aslms, inc.',
#   'aslms',
#   'american society for reproductive medicine',
#   'asrm',
#   'american society of consultant pharmacists foundation',
#   'ascp foundation',
#   'ascpf',
#   'american society of regional anesthesia and pain medicine',
#   'american society of regional anesthesia & pain medicine',
#   'asra society',
#   'asra pain medicine',
#   'asra',
#   'american society of safety engineers foundation',
#   'asse foundation',
#   'assef',
#   'american speech-language-hearing foundation',
#   'asha foundation',
#   'ashfoundation',
#   'american speech-language hearing fdn.',
#   'american speech-language-hearing fdn',
#   'american speech language hearing foundation',
#   'asha',
#   'american thyroid association',
#   'american thyroid association, lnc.',
#   'american thyroid association inc',
#   'ata',
#   'amschwand sarcoma cancer foundation',
#   'ascf',
#   'andrea-mennen family foundation',
#   'anti-slavery international',
#   'anti-slavery international, inc.',
#   'anxiety disorders association of america',
#   'adaa',
#   'aorn foundation',
#   'aplastic anemia and mds international foundation',
#   'aplastic anemia & mds international foundation',
#   'aplastic anemia & mds international foundation, inc.',
#   'aplastic anemia & mds international foundation inc',
#   'aplastic anemia and mds fdn.',
#   'aa&mdsif',
#   'aamdsif',
#   'arizona humanities council',
#   'ah',
#   'arthritis research initiative',
#   'as you sow',
#   'ays',
#   'aspirus health foundation',
#   'aspirus health foundation inc',
#   'aspirus health foundation, inc.',
#   'aspirus health',
#   'aspirus',
#   'association for glycogen storage disease',
#   'agsd',
#   'association for research on non-profit organizations & voluntary action',
#   'arnova',
#   'association of american geographers',
#   'aag',
#   'adele r. decof foundation',
#   'acaai foundation',
#   'asnr foundation',
#   'american association for the surgery of trauma',
#   'aast',
#   'albert j. ryan foundation',
#   'alex c. walker educational and charitable foundation',
#   'alex c. walker foundation',
#   'alex c walker educational & charitable foundation',
#   'alex c walker educational and charitable',
#   'alex c. walker educational & charitable foundation',
#   'arthur ashley williams foundation',
#   'aaw',
#   'aaa foundation for traffic safety',
#   'american concrete institute foundation',
#   'aci foundation',
#   'acif',
#   'aeg foundation',
#   'association of engineering geologists foundation',
#   'aegf',
#   'aesthetic surgery education and research foundation',
#   'aesthetic surgery education & research foundation',
#   'aserf',
#   'activities integrating math and science education foundation',
#   'aims education foundation',
#   'alexander foundation for orthodontic research and education',
#   'afore',
#   'alliance for epilepsy research',
#   'aer',
#   'als therapy development institute',
#   'alstdi',
#   'american academy for jewish research',
#   'american academy for jewish research inc',
#   'american academy for jewish research inc.',
#   'aajr',
#   'american academy of audiology foundation',
#   'aaa foundation',
#   'aaaf',
#   'american academy of otolaryngic allergy foundation',
#   'aaoa foundation',
#   'american academy of otolaryngic allergy foundation inc',
#   'american academy of otolaryngic allergy foundation, inc.',
#   'american academy of otolaryngic allergy/foundation',
#   'aaoaf',
#   'american alliance for health, physical education, recreation, and dance',
#   'aahperd',
#   'american anthropological association',
#   'american anthropological assn',
#   'aaa',
#   'american association of anatomists',
#   'american association of anatomists inc',
#   'aaa',
#   'american dysautonomia institute',
#   'adi',
#   'american federation for medical research',
#   'afmr',
#   'american friends of the alexander von humboldt foundation',
#   'american friends of avh',
#   'american friends avh',
#   'afavh',
#   'american hand therapy foundation',
#   'american hand therapy foundation, inc.',
#   'american hand therapy foundation inc',
#   'ahtf',
#   'american hungarian foundation',
#   'ahf',
#   'american institute of mathematics',
#   'american inst. of mathematics',
#   'aim',
#   'ajcc research foundation',
#   'american lung association in hawaii',
#   'alah',
#   'american lung association in maryland',
#   'american music therapy association',
#   'american music therapy association, inc.',
#   'amta',
#   'american occupational therapy foundation',
#   'american occupational therapy foundation inc',
#   'american occupational therapy foundation, inc.',
#   'aotf',
#   'american pain foundation',
#   'apf',
#   'american wildlife conservation foundation',
#   'american wildlife conservation foundation, inc.',
#   'american wildlife conservation foundation inc',
#   'awcf',
#   'anna needs neuroblastoma answers',
#   'anna',
#   'annenberg foundation trust at sunnylands',
#   'aetna',
#   'aetna inc.',
#   'association for frontotemporal degeneration',
#   'aftd',
#   'association for surgical education foundation',
#   'ase foundation',
#   'asef',
#   'autism research foundation',
#   'autism society of america foundation',
#   'asa foundation',
#   'affiliated american csa foundation',
#   'aacsa',
#   'associated oregon loggers',
#   'associated oregon loggers, inc.',
#   'aol',
#   'alexander h. steinkoler foundation for pancreatic cancer',
#   'alexander h. steinkoler foundation for pancreatic cancer research',
#   'adam taliaferro foundation',
#   'atf',
#   'always dream foundation',
#   'adf',
#   'advanced micro devices',
#   'amd',
#   'agilent technologies',
#   'agilent',
#   'agilent technologies, inc.',
#   'agilent technologies inc',
#   'agilent technologies inc.',
#   'amylin pharmaceuticals',
#   'astellas pharma us',
#   'astellas us llc',
#   'astellas pharma us, inc.',
#   'astellas pharma us inc',
#   'astellas us',
#   'apus',
#   'astrazeneca',
#   'astrazeneca plc',
#   'adobe systems',
#   'alcatel-lucent',
#   'alcoa',
#   'at and t',
#   'at&t',
#   'at&t inc',
#   'at&t inc.',
#   'avaya',
#   'avaya inc.',
#   'alabama power',
#   'alabama power, inc.',
#   'african development bank group',
#   'afdb',
#   'asian development bank',
#   'adb',
#   'atlantic philanthropies',
#   'association for international cancer research',
#   'aicr',
#   'accca',
#   'aga khan foundation',
#   'akf',
#   'accenture',
#   'aol',
#   'aol inc.',
#   'aol llc',
#   'america online',
#   'autodesk',
#   'autodesk, inc.',
#   'adecco',
#   'agstar financial services, aca',
#   'agstar',
#   'agstar financial services',
#   'american express company',
#   'andersen corporation',
#   'affiliated computer services',
#   'affiliated computer services, inc.',
#   'acs',
#   'american international group',
#   'american international group, inc.',
#   'aig',
#   'allied insurance',
#   'amerisure mutual insurance company',
#   'amway corporation',
#   'american honda motor',
#   'american honda motor co., inc.',
#   'american honda motor company, inc.',
#   'american honda motor company',
#   'american honda motor co.',
#   'american honda motor co',
#   'american honda motor co inc',
#   'ahm',
#   'air resources board',
#   'arb',
#   'adp',
#   'agjencia e mbrojtjes së mjedisit në kaliforni',
#   'arts board',
#   'american academy of audiology',
#   'american academy of audiology inc',
#   'am acad of audiology',
#   'american academy of audiology, inc.',
#   'aaa',
#   'altria group',
#   'altria group, inc.',
#   'ameren corporation',
#   'ashland',
#   'ashland inc.',
#   'assurant solutions',
#   'autonation',
#   'alexander von humboldt-stiftung',
#   'alexander von humboldt foundation',
#   'alexander von humboldt-stiftung/foundation',
#   'avh',
#   'american society of transplantation',
#   'ast',
#   'american educational research association',
#   'american ed research assn',
#   'aera',
#   'american academy of otolaryngology-head and neck surgery',
#   'american academy of otolaryngology–head and neck surgery, inc.',
#   'american academy of otolaryngology-head & neck surgery',
#   'american academy of otolaryngology - head and neck surgery',
#   'amacadotolaryngology',
#   'american academy of otolaryngology—head and neck surgery',
#   'american academy of otolaryngology-head and neck surgery inc',
#   'aao-hns',
#   'agency for toxic substances and disease registry',
#   'agencia para sustancias tóxicas y el registro de enfermedades',
#   'agency for toxic substances & disease registry',
#   'atsdr',
#   'aoa',
#   'a organização dos estados americanos',
#   'american nurses foundation',
#   'american nurses foundation, inc.',
#   'american nurses foundation inc.',
#   'american nurses foundation inc',
#   'anf',
#   'administration for children and families',
#   'administration for children & families',
#   'acf',
#   'arctic institute of north america',
#   'arctic institute of north america university of calgary',
#   'arctic institute',
#   'aina',
#   'academy of american poets',
#   'academy of american poets, inc.',
#   'academy of american poets incorporated',
#   'aap',
#   'american academy of arts and sciences',
#   'american academy',
#   'american academy of arts & sciences',
#   'aaas',
#   'aaa&s',
#   'american antiquarian society',
#   'aas',
#   'american association of university women',
#   'american association of university women, inc.',
#   'aauw, inc.',
#   'american association of university women inc',
#   'aauw',
#   'american center for mongolian studies',
#   'acms',
#   'amct',
#   'american institute for maghrib studies',
#   'american institute for maghrib studies inc.',
#   'american institute for maghrib studies inc',
#   'american institute for maghrib studies, inc',
#   'aims',
#   'american institute for yemeni studies',
#   'aiys',
#   'american research center in egypt',
#   'american research center in egypt, inc.',
#   'american research center in egypt, incorporated',
#   'american research center in egypt inc',
#   'arce',
#   'american research institute in turkey',
#   'american research institute',
#   'american research institute in turkey inc',
#   'american research institute in turkey, inc.',
#   'arit',
#   'american academy of pediatrics',
#   'american academy of pediatrics inc',
#   'american academy of pediatrics, inc.',
#   'aap',
#   'american association of pharmaceutical scientists',
#   'aaps',
#   'alaska conservation foundation',
#   'acf',
#   'american college of neuropsychopharmacology',
#   'american college of neuropsychopharmacology inc',
#   'american college of neuropsychopharmacology, inc.',
#   'acnp',
#   'acoustical society of america',
#   'acoustical society',
#   'asa',
#   'american chemical society',
#   'acs chemistry for life',
#   'acs',
#   'american college of surgeons',
#   'american college of surgeons inc',
#   'american college of surgeons, inc.',
#   'acs',
#   'association for institutional research',
#   'air',
#   'aist foundation',
#   'association for iron & steel technology foundation',
#   'albright institute',
#   'albright',
#   'albright institute of archaeological research',
#   'aiar',
#   'alexia foundation for world peace',
#   'alexia foundation',
#   'alexia',
#   'alexia foundation for world peace inc.',
#   'alexia foundation for world peace inc',
#   'american association of cereal chemists international foundation',
#   'american association of family and consumer sciences',
#   'american association of family & consumer sciences',
#   'american assn. of family and consumer sciences',
#   'aafcs',
#   'american association of law libraries',
#   'aall',
#   'association for asian studies',
#   'association for asian studies, inc.',
#   'association for asian studies inc',
#   'association for asian studies inc.',
#   'aas',
#   'abell foundation',
#   'abell foundation, inc.',
#   'abell foundation inc',
#   'abell foundation inc.',
#   'academy of motion picture arts and sciences',
#   'academy of motion picture arts & sciences',
#   'acad. of motion picture arts & scis.',
#   'ampas',
#   'academy of natural sciences of drexel university',
#   'academy of natural sciences',
#   'academy of natural sciences of philadelphia',
#   'academy of natural sciences - drexel university',
#   'ansp',
#   'academyhealth',
#   'academy health',
#   'american college of clinical pharmacy research institute',
#   'accp research institute',
#   'accp ri',
#   'adc foundation',
#   'advertising educational foundation',
#   'ana educational foundation',
#   'aef',
#   'afcea educational foundation',
#   'afcea ed foundation',
#   'ahima foundation',
#   'aiaa foundation',
#   'aiaa foundation inc',
#   'american institute of aeronautics and astronautics foundation',
#   'aiaa foundation inc.',
#   'aiaaf',
#   'alfred friendly press fellowships',
#   'afpf',
#   'american brain foundation',
#   'abf',
#   'alpha omega alpha honor medical society',
#   'alpha omega alpha',
#   'alpha omega alpha (αωα) honor medical society',
#   'alpha omega alpha honor society',
#   'aoa',
#   'aωa',
#   'amarillo area foundation',
#   'amarillo area foundation, inc.',
#   'amarillo area foundation inc',
#   'amarillo area foundation inc.',
#   'aaf',
#   'amateur chamber music players foundation',
#   'acmp foundation',
#   'ambucs',
#   'american academy of child and adolescent psychiatry',
#   'american academy of child & adolescent psychiatry',
#   'american association of child & adolescent psychiatry',
#   'american academy of child & adoles',
#   'aacap',
#   'aafprs foundation',
#   'aafprs foundation; educational & research foundation for the american academy of facial plastic and reconstructive surgery',
#   'aafprs',
#   'american academy of neurology',
#   'aan',
#   'american academy of nursing',
#   'american academy of nursing community',
#   'american academy of nursing inc',
#   'american academy of nursing inc.',
#   'aan',
#   'american optometric foundation',
#   'aof',
#   'american academy of periodontology foundation',
#   'aap foundation',
#   'aapfoundation',
#   'aapf',
#   'american academy of religion',
#   'american academy of religion, inc.',
#   'american academy of religion inc',
#   'aar',
#   'american architectural foundation',
#   'aaf',
#   'american association for dental, oral, and craniofacial research',
#   'american association for dental research',
#   'aadocr',
#   'association for slavic, east european, and eurasian studies',
#   'association for slavic, east european & eurasian studies',
#   ...],
#  'b': ['boeing',
#   'boeing company',
#   'boeing co',
#   'boeing co.',
#   'biological sciences (bio)',
#   'bio',
#   'bio/oad',
#   'bio/mcb',
#   'biological infrastructure',
#   'bio/dbi',
#   'bio/ios',
#   'bio/deb',
#   'bio/ef',
#   'behavioral & cognitive sciences',
#   'behavioral and cognitive sciences',
#   'bcs',
#   'bernard osher foundation',
#   'burroughs wellcome fund',
#   'bwf',
#   'bill and melinda gates foundation',
#   'bill & melinda gates foundation',
#   'bmgf',
#   'b&mgf',
#   'brain and behavior research foundation',
#   'brain & behavior research foundation',
#   'brain & behavior research fdn',
#   'bbrf',
#   'brain research foundation',
#   'brain research fdn',
#   'brf',
#   'brown foundation',
#   'brown foundation, inc.',
#   'brown foundation inc',
#   'broad foundation',
#   'bradley foundation',
#   'bell-hanger foundation, inc.',
#   'ball brothers foundation',
#   'baptist community ministries',
#   'bcm',
#   'barry community foundation',
#   'bcf',
#   'baton rouge area foundation',
#   'braf',
#   'battelle',
#   'battelle memorial institute',
#   'battelle memorial institute, inc.',
#   'battelle memorial institute inc.',
#   'battelle memorial institute inc',
#   'bmi',
#   'battle creek community foundation',
#   'bccf',
#   'beckman foundation',
#   'berkshire taconic community foundation',
#   'blue shield of california foundation',
#   'bsc foundation',
#   'blue shield of ca foundation',
#   'bscf',
#   'boehringer ingelheim',
#   'boehringer ingelheim pharmaceuticals, inc.',
#   'boehringer ingelheim pharmaceuticals inc',
#   'bi',
#   'bipi',
#   'bohemian foundation',
#   'bonfils-stanton foundation',
#   'bonfils stanton foundation',
#   'bonfils-stanton fndn',
#   'bsf',
#   'breast cancer research foundation',
#   'bcrf',
#   'brinson foundation',
#   'bristol-myers squibb foundation',
#   'bmsf',
#   'brown foundation',
#   'buhl foundation',
#   'buhl foundation, inc.',
#   'buhl foundation inc',
#   'buoniconti fund to cure paralysis',
#   'buoniconti fund',
#   'buoniconti fund to cure paralysis, inc.',
#   'buoniconti fund to cure paralysis inc',
#   'buoniconti fund to cure paralysis inc.',
#   'boomer esiason foundation',
#   'bef',
#   'brookdale foundation',
#   'billings clinic foundation',
#   'bay and paul foundations',
#   'bay & paul foundations',
#   'bay and paul foundations, inc.',
#   'bay & paul foundations inc',
#   'bay and paul foundations inc',
#   'bodman foundation',
#   'bluecross blueshield of south carolina foundation',
#   'bluecross foundation',
#   'bluecross blueshield of sc foundation',
#   'bcbs of sc foundation',
#   'bachmann-strauss dystonia and parkinson foundation',
#   'bachmann-strauss dystonia & parkinson foundation, inc.',
#   'bachmann-strauss dystonia & parkinson foundation inc',
#   'bsdpf',
#   'bailey family foundation',
#   'bff',
#   'bernice barbour foundation',
#   'bernice barbour foundation, inc.',
#   'bernice barbour foundation inc',
#   'bernice barbour foundation inc.',
#   'bay area community foundation',
#   'bacf',
#   'beckman laser institute and medical clinic',
#   'bli',
#   'belgian american educational foundation',
#   'belgian american educational foundation inc.',
#   'belgian american educational foundation, inc.',
#   'belgian-american educational foundation',
#   'belgian american educational foundation inc',
#   'baef',
#   'b.a.e.f.',
#   'berks county community foundation',
#   'beveridge family foundation',
#   'beveridge family foundation, inc.',
#   'beveridge family foundation inc',
#   'bff',
#   'blowitz-ridgeway foundation',
#   'blowitz ridgeway foundation',
#   'blue and you foundation for a healthier arkansas',
#   'blue & you foundation',
#   'blue & you foundation for a healthier arkansas',
#   'blue cross blue shield of michigan foundation',
#   'bcbsm foundation',
#   'blue cross and blue shield of michigan foundation',
#   'bcbsmf',
#   'blumenthal foundation',
#   'breast cancer alliance',
#   'breast cancer alliance, inc.',
#   'breast cancer alliance inc',
#   'breast cancer alliance inc.',
#   'bca',
#   'brentwood foundation',
#   'britton fund',
#   'britton fund, inc.',
#   'britton fund inc',
#   'bugher foundation',
#   'ben and maytee fisch foundation',
#   'ben & maytee fisch foundation',
#   'be the match foundation',
#   'bar foundation',
#   'beaver county foundation',
#   'bcf',
#   'biomedical research foundation of northwest louisiana',
#   'brf',
#   "bloom's syndrome foundation",
#   'bsf',
#   'bryan area foundation',
#   'bryan area foundation, inc.',
#   'blanche moore foundation',
#   'bridgestone americas',
#   'bridgestone americas, inc.',
#   'bsa',
#   'bank of america',
#   'brookdale foundation group',
#   'bfg',
#   'bristol-myers squibb',
#   'bristol-myers squibb company',
#   'bristol myers squibb co.',
#   'bristol myers squibb',
#   'bms',
#   'baltic-american partnership fund',
#   'bapf',
#   'barrett bateman foundation',
#   'barth syndrome foundation',
#   'barth syndrome foundation, inc.',
#   'barth syndrome foundation inc',
#   'barth syndrome',
#   'barth syndrome foundation inc.',
#   'bsf',
#   'beckman coulter foundation',
#   'beez foundation',
#   'beez foundation, inc.',
#   'benton foundation',
#   'blacksmith institute',
#   'blacksmith institute, inc.',
#   'bradshaw-knight foundation',
#   'bradshaw-knight foundation, inc.',
#   'breast cancer help',
#   'breast cancer help, inc.',
#   'breast health institute',
#   'bhi',
#   'broad foundation',
#   'bruner foundation',
#   'bruner foundation, inc.',
#   'buffalo bills youth foundation',
#   'bynner foundation for poetry',
#   'bernice e. holland foundation',
#   'brain tumor treatments and information',
#   'brian piccolo cancer research fund',
#   'brian piccolo cancer research fund inc',
#   'brian piccolo cancer research fund inc.',
#   'brian piccolo cancer research fund, inc.',
#   "ben's dream - the sanfilippo research foundation, inc.",
#   "ben's dream - sanfilippo research foundation",
#   "ben's dream sanfilippo research foundation",
#   "ben's dream",
#   'bakken museum',
#   'bluecross of idaho foundation for health',
#   'bluecross of idaho foundation for health inc.',
#   "boeing's global corporate citizenship",
#   "boeing's gcc",
#   'brenen hornstein autism research & education foundation',
#   'bhare foundation',
#   'brad kamisky foundation',
#   'bayer',
#   'bayer ag',
#   'basf',
#   'bp',
#   'bp p.l.c.',
#   'blue cross blue shield of massachusetts',
#   'blue cross blue shield of massachusetts, inc.',
#   'brother international corporation',
#   'banco mundial',
#   'banque mondiale',
#   'banco interamericano de desenvolvimento',
#   'banque interaméricaine de développement',
#   'banco interamericano de desarrollo',
#   'bid',
#   'bioversity international',
#   'berkshire hathaway',
#   'berkshire hathaway inc.',
#   'booz allen hamilton',
#   'bah',
#   'black & decker',
#   'bdk',
#   'barnes & noble',
#   'barnes & noble, inc.',
#   'b&n',
#   'baxter international',
#   'baxter international inc.',
#   'baxter',
#   'baxter international inc',
#   'baxter laboratories, inc.',
#   'bloomberg l.p.',
#   'bmw of north america',
#   'bmw of north america, llc',
#   'bmw na',
#   'bon',
#   'ball corporation',
#   'bmc software',
#   'bmc software, inc.',
#   'bmc',
#   'borders',
#   'bureau of justice assistance',
#   'bja',
#   "brigham and women's hospital",
#   "brigham and women's hospital, inc.",
#   "brigham & women's hospital inc.",
#   "brigham and women's",
#   'brigham hospital',
#   "brigham & women's hospital",
#   'bwh',
#   'boston college',
#   'bc',
#   'bfa',
#   'bfa/oad',
#   'budget division',
#   'budget division (bd)',
#   'bd',
#   'bfa/bd',
#   'bfa/dacs',
#   'bfa/dfm',
#   'bfa/dga',
#   'bfa/dias',
#   'baltimore community foundation',
#   'baltimore community foundation, inc.',
#   'baltimore community foundation inc',
#   'baltimore community foundation inc.',
#   'bcf',
#   'bat conservation international',
#   'bat conservation international, inc.',
#   'bat conservation international inc',
#   'bci',
#   'barbara bates center for the study of the history of nursing, university of pennsylvania',
#   'barbara bates center',
#   'barbara bates center for the study of the history of nursing',
#   'barbara bates center for the study of the history of nursing at the university of pennsylvania',
#   'bates center',
#   'bbcshn',
#   'batten disease support and research association',
#   'batten disease support & research association',
#   'batten disease support & research assoc',
#   'bdsra',
#   'beckman institute for advanced science and technology, university of illinois, urbana-champaign',
#   'beckman institute for advanced science and technology',
#   'beckman institute',
#   'beckman institute for advanced science and technology at the university of illinois at urbana-champaign',
#   'beckman institute for advanced science & technology',
#   'beckman institute - university of illinois at urbana',
#   'beckman institute for advanced science & technology at the university of illinois at urbana-champaign',
#   'beckman institute for advanced science and technology university of illinois urbana-champaign',
#   'beckman institute at illinois',
#   'beckmaninstitute',
#   'beinecke rare book and manuscript library, yale university',
#   'beinecke rare book & manuscript library',
#   'beinecke library',
#   'beinecke rare book and manuscript library',
#   'beinecke rare book library',
#   'beinecke rare book & manuscript library, yale university',
#   'beinecke library at yale',
#   'beinecke rare book & manuscript library - yale university',
#   'beinecke rare book & manuscript library at yale university',
#   'beinecke rare book and manuscript library at yale university',
#   'brbml',
#   'belfer center for science and international affairs, harvard university',
#   'belfer center for science and international affairs',
#   'belfer center',
#   'bcsia',
#   'bemis center for contemporary arts',
#   'bemis center',
#   'bemis center for contemporary arts inc',
#   'bcca',
#   'bentley historical library, university of michigan',
#   'bentley historical library',
#   'bentley historical library - university of michigan',
#   'bhl',
#   'beta phi mu',
#   'beta phi mu honor society',
#   'beta phi mu - the international library and information studies honor society',
#   'beta phi mu international honor society',
#   'bpm',
#   'brown university/john carter brown library',
#   'bibliothèque john carter brown',
#   'biblioteca john carter brown',
#   'biblioteka john carter brown',
#   'bush foundation',
#   'bibliographical society of america',
#   'bibliographical society of america inc',
#   'bibliographical society of america, inc.',
#   'bsa',
#   'bird foundation',
#   'binational industrial research and development foundation',
#   'binational industrial research & development foundation',
#   'bird',
#   'biomedical engineering society',
#   'bmes',
#   'black metropolis research consortium',
#   'bmrc',
#   'blakemore foundation',
#   'blakemore foundation-seattle',
#   'blakemorefoundation',
#   'blue cross and blue shield of florida foundation',
#   'blue cross and blue shield of florida foundation, inc.',
#   'blue cross blue shield of florida foundation, inc.',
#   'blue cross and blue shield of florida foundation inc',
#   'blue cross and blue shield of florida foundation inc.',
#   'blue cross blue shield of fl foundation',
#   'blue cross/blue shield of florida foundation',
#   'bmi foundation',
#   'bmi foundation, inc.',
#   'bmi foundation, inc',
#   'bmi foundation inc.',
#   'bmi foundation inc',
#   'bmif',
#   'boettcher foundation',
#   'borchard foundation center on law and aging',
#   'borchard foundation center on law & aging',
#   'boston athenaeum',
#   'boston athenæum',
#   'boston society of architects',
#   'bsa',
#   "brain tumor funders' collaborative",
#   'brain tumor funders collaborative',
#   'btfc',
#   'braitmayer foundation',
#   'bread and roses community fund',
#   'bread & roses community fund',
#   'bread & roses',
#   'brcf',
#   "bread loaf writers' conference, middlebury college",
#   "bl writers'",
#   'bread loaf writers’ conferences',
#   'briscoe center',
#   'briscoe center for american history',
#   'briscoecenter',
#   'bcah',
#   'bullitt foundation',
#   'byrd polar research center, ohio state university',
#   'bprc',
#   'boston foundation for architecture',
#   'bfa',
#   'boston college center for retirement research',
#   'biogen',
#   'biogen inc.',
#   'biogen inc',
#   'beth israel deaconess medical center',
#   'beth israel deaconess medical center inc',
#   'beth israel deaconess medical center, inc.',
#   'beth israel deaconess medical center inc.',
#   'bidmc',
#   'bluecross blueshield of north carolina foundation',
#   'bcbsnc foundation',
#   'blue cross and blue shield of north carolina foundation',
#   'blue cross and blue shield of north carolina (bcbsnc) foundation',
#   'blue cross nc foundation',
#   'bcbsncf',
#   'biofuels center of north carolina',
#   'baxter international foundation',
#   'baxter international',
#   'bif',
#   'black studies department',
#   'black studies at uc santa barbara',
#   'bill and carol fox center for humanistic inquiry, emory university',
#   'bill and carol fox center for humanistic inquiry',
#   'biochemical society',
#   'bard us israel binational agricultural r&d',
#   'bard us-israel agricultural research and development fund',
#   'bard the us-israel binational agricultural r&d',
#   'bard - us israel binational agricultural research and development fund',
#   'bard the u.s.-israel binational agricultural research and development fund',
#   'binational agricultural research and development fund',
#   'binational agricultural research & development fund',
#   'bi-national agricultural research & development',
#   'bard',
#   'bogliasco foundation',
#   'bogliasco foundation, inc.',
#   'bogliasco foundation inc',
#   'bf',
#   'bone and joint initiative usa',
#   'bone and joint decade canada',
#   'bjdc',
#   'basic energy sciences',
#   'bes',
#   'biomass program',
#   'building technologies program',
#   'biological and environmental research',
#   'ber',
#   'bsf',
#   'brookhaven national laboratory',
#   'brookhaven national lab',
#   'brookhaven lab',
#   'bnl',
#   'berkeley lab',
#   'brightfocus foundation',
#   'brightfocus',
#   'bff',
#   'biogen idec',
#   'butler university',
#   'butler',
#   'ben b. and iris m. margolis foundation',
#   'bone and joint injury prevention and rehabilitation center, university of michigan',
#   'bone and joint injury prevention centre of the university of michigan',
#   'brown university',
#   'brown',
#   'bucknell university',
#   'bureau for economic growth, education, and environment, united states agency for international development',
#   'bureau of reclamation',
#   'bureau of reclamation. u.s. department of the interior',
#   'bor',
#   'br',
#   'baker hughes',
#   'baker hughes inc.',
#   'baker hughes incorporated',
#   'biodiversity institute, florida museum of natural history',
#   'bard college student government',
#   'bard college student council',
#   'bowling green state university',
#   'bgsu',
#   'benjamin and mae swig foundation',
#   'bay area black united fund',
#   'babuf',
#   'boston foundation',
#   'boys town',
#   'boston safe deposit and trust company',
#   'bny mellon',
#   'brigham young university',
#   'byu',
#   'bureau of safety and environmental enforcement',
#   'bsee',
#   'bureau of educational and cultural affairs',
#   'biology department, gannon university',
#   "boston children's hospital",
#   'bch',
#   'bernard and esther besner infant research fund',
#   'basis international',
#   'board of regents',
#   'board of regents state of louisiana',
#   "benjamin and adith miller family endowment on aging, alzheimer's, and autism research",
#   'brady education foundation',
#   'brady education foundation, inc.',
#   'brady education foundation inc',
#   'brady education foundation inc.',
#   'brady foundation',
#   'bef',
#   'buck foundation',
#   'bureau of land management',
#   'blm',
#   'boston university',
#   'bu',
#   'barry university',
#   "bunning food allergy institute, ann and robert h. lurie children's hospital of chicago",
#   'bert l. & n. kuggie vallee foundation',
#   'boise state university',
#   'bosie state',
#   'bsu',
#   'boston university school of medicine',
#   'baylor health care system foundation',
#   'barnes-jewish hospital foundation',
#   'bank of sardinia foundation',
#   'belgian association against neuro-muscular diseases',
#   'bbva foundation',
#   'bernard van leer foundation',
#   'brocher foundation',
#   'basf corporation',
#   'basf schweiz',
#   'basf suisse',
#   'bausch and lomb',
#   'bausch & lomb',
#   'bausch and lomb ireland',
#   'baylor university',
#   'baylor',
#   'biofrontiers institute, university of colorado boulder',
#   'biomedical laboratory research and development, va office of research and development',
#   'biomedical laboratory research and development service of the va office of research and development',
#   'blr&d, ord',
#   'biosense webster',
#   'blanchette hooker rockefeller fund',
#   'bloomberg family foundation',
#   'blue cross and blue shield association',
#   'bcbs',
#   'blum center for developing economies, university of california berkeley',
#   'blum center',
#   'bosack and kruger foundation',
#   'boston medical center',
#   'bmc',
#   'broitman foundation',
#   'bombardier',
#   'bombardier inc.',
#   'bombardier transportation',
#   'b. braun melsungen',
#   'b. braun melsungen ag',
#   'b. braun medical',
#   'boler family foundation',
#   'bulgarian biodiversity foundation',
#   'bbf',
#   'bau',
#   'belarusian republican foundation for fundamental research',
#   'brffr',
#   'bloddonorerne i danmark',
#   'blood donors in denmark',
#   'bourns college of engineering, university of california, riverside',
#   'bourns college of engineering',
#   'bourns engineering',
#   'bcoe',
#   'bowland charitable trust',
#   'boyce thompson institute for plant research',
#   'boyce thompson institute for plant research inc.',
#   'bti',
#   'biotechnology institute, ankara university',
#   'biomimetic therapeutics',
#   'biomimetic therapeutics, inc.',
#   'biomimetic therapeutics, llc',
#   'biomimetic',
# ...
#   '公益財団法人石橋由紀子記念基金',
#   '1. the academy of applied science 2. academy of applied science, inc.',
#   '日立金属 · 材料科学財団',
#   'বাংলাদেশ বিশ্ববিদ্যালয় মঞ্জুরী কমিশন',
#   'татарстан республикасы хөкүмәте',
#   'правительство республики татарстан',
#   '中国清洁发展机制基金',
#   '宁夏回族自治区教育厅',
#   '安徽省高等教育振兴计划',
#   '西安市红会医院',
#   '株洲市人民政府 承办单位',
#   '吉林省发展和改革委员会',
#   '安徽省质量工程',
#   '中国航空技术进出口公司',
#   '腾讯控股有限公司',
#   '中国计算机学会',
#   '中國計算機學會',
#   '天津市工业和信息化委员会',
#   '吉林市生态环境局',
#   '石家庄铁道大学',
#   '中华人民共和国自然资源部',
#   '中華人民共和國自然資源部',
#   '中国煤炭科工集团有限公司 维护单位',
#   '宁夏回族自治区科学技术厅',
#   '国家旅游局',
#   '國家旅游局',
#   '衛生福利部桃園醫院',
#   'けいゆう病院',
#   'ナノ材料マイクロデバイス研究センター',
#   '佐賀県庁',
#   '사가 현청',
#   '佐贺县政府',
#   '佐賀縣政府',
#   '中国国家铁路集团有限公司',
#   '晋中学院',
#   '中国营养学会',
#   'جامعہ زرعیہ پشاور، یا زرعی یونیورسٹی پشاور',
#   'د کرنې پوهنتون، پېښور',
#   '内田エネルギー科学振興財団',
#   '安徽省住房和城乡建设厅',
#   '1563 foundation for art and culture',
#   'サノフィ株式会社',
#   '興和株式会社',
#   '国立大学法人 京都工芸繊維大学',
#   '三重大学',
#   '三重大',
#   '淑徳大学',
#   '日本生化学会は',
#   'جامعة الأخوين',
#   'جامعة مولاي إسماعيل',
#   'جامعہ وسطی پنجاب',
#   '陕西省中医药管理局',
#   '上海市质量技术监督局',
#   '北京市哲学社会科学规划办公室',
#   '上海市浦东新区周浦医院',
#   '上海市中西医结合学会',
#   '西安欧亚学院',
#   '新疆维吾尔自治区科学技术厅',
#   '安徽省人力资源和社会保障厅',
#   '江西省人力资源和社会保障厅',
#   '河北省人力资源和社会保障厅',
#   '年上海市药理学会',
#   '广东省人力资源和社会保障厅',
#   '曲阜师范大学',
#   '曲阜師範大學',
#   '上海市国有资产监督管理委员会',
#   '上海工程技术研究中心建设与管理办法',
#   'обща селскостопанска политика',
#   'ühine põllumajanduspoliitika',
#   'κοινή γεωργική πολιτική',
#   'европа за гражданите',
#   'ευρώπη για τους πολίτες',
#   'российский экономический университет имени г.в. плеханова',
#   '俄罗斯普列汉诺夫经济大学',
#   '公益社団法人 日本麻酔科学会',
#   'สถาบันวิจัยวิทยาศาสตร์และเทคโนโลยีแห่งประเทศไทย',
#   '原子力規制委員会',
#   'エジプト日本科学技術大学',
#   'الجامعة المصرية اليابانية للعلوم والتكنولوجيا',
#   'معرض421',
#   'مركز الحسين للسرطان',
#   '三菱重工業株式会社',
#   '日本血液製剤機構',
#   'ราชวิทยาลัยจุฬาภรณ์',
#   '応用物理学会',
#   '公益社団法人 応用物理学会',
#   'ōyō butsuri gakkai',
#   '公益財団法人ウエスコ学術振興財団',
#   'চট্টগ্রাম বিশ্ববিদ্যালয়',
#   '公益財団法人 内藤科学技術振興財団',
#   '株式会社セルシード',
#   '富山大学',
#   '국립생태원',
#   'یونیورسٹی آف ملاکنڈ',
#   'ملاکنډ پوهنتون',
#   'جامعہ مالاکنڈ',
#   '学校法人産業医科大学',
#   '日本製薬株式会社',
#   '中山人間科学振興財団',
#   'ボストン・サイエンテ',
#   '帝京大学医学部附属溝',
#   'ижевский государственный технический университет',
#   'جامعة الباحة',
#   '(mc)2',
#   'международного медицинского центра',
#   '분당 서울대병원',
#   'جامعہ فیصل آباد',
#   'министерство образования оренбургской области',
#   '公益財団法人大樹生命厚生財団',
#   'สถาบันวิจัยดาราศาสตร์แห่งชาติ',
#   '財團法人國家實驗研究院',
#   '财团法人国家实验研究院',
#   '메드트로닉',
#   '美敦力',
#   '公益社団法人 日本農芸化学会',
#   '대한심장학회',
#   '고려 대학교 구로 병원',
#   'स्वास्थ्य तथा जनसन्ख्या मन्त्रालय',
#   '公益財団法人海洋化学研究所',
#   '公益財団法人 上廣倫理財団',
#   '公益財団法人 東燃ゼネラル石油研究奨励・奨学財団',
#   '公益財団法人 綿貫国際奨学財団',
#   '人工知能研究振興財団',
#   '江野科学振興財団',
#   '公益財団法人 骨粗鬆症財団',
#   '國軍退除役官兵輔導委員會',
#   'đại học đà nẵng',
#   'اقرا یونیورسٹی',
#   'پاکستان انسٹی ٹیوٹ آف انجینئرنگ اینڈ اپلائیڈ سائنسز',
#   'یونیورسٹی آف انجینئرنگ اینڈ ٹیکنالوجی، لاہور',
#   'جامعة عبدالملك السعدي',
#   'みやりさん製薬',
#   '日本臓器製薬',
#   'エア・ウォーター・メディカルは',
#   '情報処理学会',
#   '富山大学 和漢医薬学総合研究所',
#   '日本糖尿病協会',
#   '日本生理人類学会',
#   '玉川大学',
#   '東京都市大学',
#   '都市大',
#   '東京電機大学',
#   '公益社団法人富山県医師会',
#   'υπουργείο περιβάλλοντος και ενέργειας',
#   'υπουργείο αγροτικής ανάπτυξης και τροφίμων',
#   '香港城市大学深圳研究院',
#   '公益財団法人 東京都医学総合研究所',
#   'جامعة العلوم التطبيقية الخاصة',
#   '東北電力株式会社',
#   '日本整形外科学会',
#   'دانشگاه ملایر',
#   '公益財団法人かずさ dna 研究所',
#   '日本化学工業協会',
#   '北陸先端科学技術大学院大学',
#   'восточно-сибирский государственный университет технологий и управления',
#   'всгуту',
#   'östergötland region',
#   '公益財団法人吉田育英会',
#   '九州電力株式会社',
#   '住友電気工業株式会社',
#   '广东珠江人才计划',
#   '宁夏重点研发项目',
#   '海洋公益性行业科研专项项目',
#   '山东省科技发展计划',
#   '国家自然科学基金理论物理专款',
#   '国家自然科学基金与贵州省喀斯特科学研究中心联合基金',
#   '国家基础科学人才培养基金',
#   'جامعة الشارقة',
#   '奧林巴斯香港中國有限公司',
#   '奧林巴斯香港',
#   'الجامعة الاسلامية في رياو',
#   'जीवाजी विश्वविद्यालय, ग्वालियर',
#   'सेंट्रल यूनिवर्सिटी ऑफ़ तमिलनाडु',
#   'स्नातकोत्तर चिकित्सा शिक्षा एवं अनुसंधान संस्थान, चंडीगढ़',
#   'طرح چشمه\u200cی نور ایران',
#   '岸本財団',
#   '京都薬科大学',
#   '立松財団',
#   '鳥居薬品株式会社',
#   '四国電力',
#   '한국학 진흥 서비스',
#   '日本学術会議',
#   '岩手医科大学',
#   '고급 메타 물질 센터',
#   '파동에너지극한제어연구단',
#   '케이티 주식회사',
#   '朝陽科技大學',
#   'уряд україни',
#   '국립산림과학원',
#   'đại học lạc hồng',
#   '运城学院',
#   '重庆市卫生健康委员会',
#   'école des hautes etudes en sciences sociales',
#   '京都大学 ウイルス・再生医科学研究所',
#   '株式会社 島津製作所',
#   '國立政治大學',
#   '造船学術研究推進機構',
#   '松尾学術振興財団',
#   'สถาบันส่งเสริมการสอนวิทยาศาสตร์และเทคโนโลยี',
#   '微软亚洲研究院',
#   '深圳市卫生信息中心',
#   'پژوهشگاه نیرو',
#   'دانشگاه علوم کشاورزی و منابع طبیعی ساری',
#   'پژوهشگاه استاندارد',
#   '公益財団法人\u3000篷\u3000庵\u3000社',
#   '公益財団法人 篷庵社',
#   '国立循環器病センター',
#   '般財団法人 武田計測先端知財団',
#   '京都大学基金事',
#   '国立自然科学博物館',
#   '白求恩公益基金会',
#   '般財団法人 糧食研究会',
#   '公益財団法人福岡直彦記念財団',
#   '福島県ホ',
#   '工学院大学',
#   '南山大学',
#   '帯広畜産大学',
#   '大塚敏美育英奨学財団',
#   '日本薬学会',
#   '山形大学',
#   '山口大学',
#   '公益財団法人 八洲環境技術振興財団\u3000設立趣意',
#   '公益財団法人 奈良先端科学技術大学院大学支援財団は',
#   '日本全薬工業株式会社',
#   '生体医歯工学共同研究拠点',
#   '전북 대학교 병원의 생명 연구원',
#   '고려대학교의료원',
#   'монгол улсын их сургууль',
#   'काठमाडौं विश्वविद्यालय',
#   'اسلامیہ یونیورسٹی بہاولپور',
#   '서울대학교 의과대학',
#   '国家自然科学基金委员会—辽宁联合基金',
#   '国家自然科学基金委员会—新疆维吾尔自治区人民政府联合基金',
#   '国家自然科学基金-浙江省工业化与信息化融合联合基金',
#   '国家自然科学基金委-山东省联合基金项目',
#   '省部共建煤炭高效利用与绿色化工国家重点实验室',
#   'وزارة التعليم العالي والبحث العلمي',
#   'ұлттықғылыми-техникалық сараптама орталығы',
#   'национальный центр государственной научно-технической экспертизы',
#   'ұмғтсо',
#   'нцгнтэ',
#   'ソニー株式会社',
#   '住友化学株式会社',
#   '株式会社 東レリサーチセンター',
#   'ヤマハ発動機株式会社',
#   '浦上食品・食文化振興財団',
#   '横浜市立大学',
#   '公益財団法人i-o data財団',
#   '国家航天局',
#   '中国石油天然气集团有限公司',
#   '深圳',
#   '安徽省杰出青年自然科学基金',
#   '季华实验室',
#   '国家超级计算广州中心',
#   '浙江大学网络空间治理研究所',
#   '合成生物学国家重点工程',
#   '北京物流信息学研究基地',
#   '商用飞机制造国家工程与研究中心',
#   '삼성 메디슨',
#   'بنى سويف',
#   'университета бени-суэфа',
#   '日医工株式会社',
#   'क्षेत्रीय जैवप्रौद्योगिकी केन्द्र',
#   '国家电网福建省电力公司',
#   '湖北省防灾减灾重点实验室',
#   '小米研究',
#   '埼玉県立循環器・呼吸器病センター',
#   '邵逸夫医院',
#   '百济神州的',
#   '国立食品药品监督管理局',
#   '国家食品药品监督管理总局',
#   '司法鉴定科学研究院 上海市法医学重点实验室',
#   'האוניברסיטה הפתוחה',
#   'جامعة المنستير',
#   'جامعة الكوفة',
#   '東京海洋大学',
#   '土木研究所は',
#   '公益社団法人 日本船舶海洋工学会',
#   'دانشگاه علوم پزشکی رفسنجان',
#   '国土资源部资源与环境承载力重点实验室',
#   '广东省结构性出生缺陷病研究重点实验室',
#   '吉林省先进能源材料重点实验室',
#   '甲南学園学術研究財団平尾太郎財団',
#   'ベーリンガーインゲルハイムジャパン',
#   '日東',
#   '米山ロータリー記念財団',
#   '电站自动化技术上海市重点实验室',
#   '北京市腹膜表面肿瘤医学人才研究基金',
#   '上海市压力管道智能检测工程研究中心',
#   '군사 암호화 연구 센터',
#   '江西省研究生创新专项基金项目',
#   '宁波市生命科学与健康创新团队',
#   '福建省科技计划',
#   '哈尔滨应用技术研发项目',
#   '山东省应用技术创新重点农业项目',
#   '航天化学动力实验室科学技术开放研究计划',
#   '广西光电信息处理重点实验室',
#   '南宁师范大学物流工程创新实验室',
#   '杭州社会科学研究的发展',
#   '天津市高中科技基金计划项目',
#   '中国天津市交通科技发展规划',
#   '黑龙江省重点研究开发计划',
#   '陕西省科技新星研究基金',
#   '四川省国际科技合作计划',
#   '广州市科技规划项目',
#   '四川高等学校绿色化学重点实验室开放项目',
#   '山西煤层气联合基金会',
#   '江苏省高校中青年教师和校长海外研究培训计划',
#   '"13th five-year" plan of philosophy and social science development in guangzhou',
#   '广州市哲学社会科学“十三五”发展规划',
#   '湖北省农业电子商务协同创新中心',
#   '上海市临床老年医学重点实验室',
#   '广东省肾脏病重点实验室',
#   '山西省清洁能源研究所',
#   '上海市呼吸系统疾病重点学科',
#   '北京食品添加剂工程技术研究中心',
#   '深圳市科学技术基金会',
#   '山东省现代农业产业技术体系创新团队项目',
#   'агенция за ядрено регулиране',
#   'институт физики микроструктур ран',
#   '广东省透明导电材料工程技术研究中心',
#   '高分子学会',
#   '日本私立学校振興財団',
#   'русенски университет „ангел кънчев“',
#   '"angel kanchev" university of ruse',
#   '北京服装学院',
#   'राष्ट्रीय प्रौद्योगिकी संस्थान अगरतला',
#   'جامعة كفر الشيخ',
#   'राष्ट्रीय उन्नत अध्ययन संस्थान',
#   '曲阜师范大学实验室开放基金会',
#   '北京市社科基金项目',
#   '北京大学 第一医院',
#   '中国科学院南美天文中心',
#   'የወለጋ ዩኒቨርሲቲ',
#   '中国地方整備局',
#   '茨城大学',
#   'костромской государственный университет',
#   'эстонский литературный музей',
#   '新疆维吾尔自治区人民政府',
#   '辽宁省人民政府',
#   '新疆兵团青年科技创新基金',
#   '新疆兵团优秀青年创新资金专项',
#   '山东省杰出青年自然科学基金',
#   '山东省杰出青年科学基金',
#   '上海“联盟计划”',
#   '2-en:ieee comsoc',
#   '日本動脈硬化学会',
#   '技術研究組合次世代3d積層造形技術総合開発機構',
#   '中京大学',
#   '日本アイバンク協会',
#   'جامعة حفر الباطن',
#   '阿里巴巴达摩院',
#   '中国通信学会',
#   '한국식품산업클러스터진흥원',
#   '广东省高等学校结构与风洞重点实验室',
#   '重庆市科卫联合医学科研项目',
#   '重庆市卫生和计划生育委员会',
#   '广东省数字信号与图象处理技术重点实验室',
#   '四川省科学技术协会',
#   '大原薬品工業株式会社',
#   '酪農学園大学',
#   '成都医学院',
#   'دانشکده فنی و مهندسی گلپايگان',
#   '年金属矿山安全与健康国家重点实验室',
#   '天津理工大学',
#   '1000 talents sichuan program',
#   '四川千人计划',
#   '中国航空工业集团公司',
#   '3-en:aviation industry corporation of china limited',
#   '湖南网数科技有限公司',
#   '广东省水禽健康养殖重点实验室',
#   'đại học sư phạm kỹ thuật thành phố hồ chí minh',
#   '内蒙古医科大学',
#   '日立建機',
#   '日立建機株式会社',
#   '東京品川病院',
#   'институт за физику београд',
#   'мирэа – российский технологический университет',
#   'российский технологический университет',
#   'тошкент тиббиёт академияси',
#   'ташкентская медицинская академия',
#   'राष्ट्रीय प्रौद्योगिकी संस्थान वारंगल',
#   '特殊功能材料与结构设计教育部重点实验室',
#   '长飞光纤光缆股份有限公司',
#   '河南驼人医疗器械集团有限公司 医用高分子材料技术与应用实验室',
#   '上海市抗癌协会',
#   '河南中医药大学',
#   '上海电机学院',
#   'ウシオ電機株式会社',
#   'コマツ',
#   '株式会社小松製作所',
#   '高性能土木工程材料国家重点实验室',
#   '牡丹江市科学技术局',
#   '上海同济高廷耀环保科技发展基金会',
#   '国家食品安全风险评估中心',
#   '宝鸡市科学技术委员会',
#   '中国教师发展基金会',
#   '中韩海洋科学共同研究中心',
#   '한중해양과학공동연구센터',
#   '福建省林业厅',
#   '巨量資料及統計中心',
#   '佛山市克恩智能电器有限公司',
#   '株式会社トプコン',
#   '日本血液学会',
#   '三谷研究開発支援財団は',
#   '財団法人三谷育英会',
#   '兵庫県立大学',
#   '江苏省林业局',
#   '湖南省卫生健康委员会',
#   '广州市妇女儿童医疗中心',
#   '湖南省交通运输厅',
#   '浙江省农业农村厅',
#   '大庆市科技局',
#   '赣州市科学技术局',
#   '의학연구소',
#   '宜昌市自然科学基金',
#   '国家肉鸡产业技术体系',
#   '昆明市科学技术局',
#   '昆明市人力资源和社会保障局',
#   '信达生物制药',
#   '河南省交通运输厅',
#   '广州南洋理工职业学院',
#   'مرکز تحقیقات و آموزش کشاورزی و منابع طبیعی فارس',
#   '中国电力国际发展有限公司',
#   '盧勝彥佈施基金會',
#   '紀州田辺うめ振興協議会',
#   '公益財団法人タカセ国際奨学財団',
#   '日本外科学会',
#   '动力电池国家地方联合工程实验室',
#   '东北师范大学 动力电池国家地方联合工程实验室',
#   'ศูนย์ความเป็นเลิศด้านคณิตศาสตร์ มหาวิทยาลัยมหิดล',
#   '愛知学院大学',
#   '日本分子生物学会',
#   '中部科学技術センター',
#   '帯広畜産大学 原虫病研究センター',
#   '公益財団法人イオン環境財団',
#   '公益财团法人永旺环境财团',
#   '日本bdは',
#   '日本ベクトン・ディッキンソン株式会社',
#   'مبادرة الشراكة الرمريكية الشرق طوسطية',
#   '无锡市科学技术协会',
#   '保尔森基金会',
#   '深圳市教育学会',
#   '扬州市财政局举报 分享',
#   '黄鹤英才(科技)计划项目',
#   '武汉市人力资源和社会保障局',
#   '国家固态酿造工程技术研究中心',
#   '. 国家钛及稀有金属粉末冶金工程技术研究中心',
#   'राजकीय इंजीनियरिंग कॉलेज, अम्बेडकर नगर',
#   'जवाहरलाल नेहरू विश्वविद्यालय',
#   '孫正義育英財団',
#   'جامعہ باچاخان .باچا خان پوهنتون',
#   '寶齡富錦生技股份有限公司',
#   '寶齡富錦生技',
#   '河北省卫生和计划生育委员会',
#   'ライオン株式会社',
#   '河北省博士后科学基金',
#   '四川省博士后科学基金',
#   '浙江省博士后基金',
#   '湖北省博士后科学基金',
#   '"广东省博士后科学基金"',
#   '甘肃省博士后科学基金',
#   '海南省博士后科学基金',
#   '吉林省博士后科学基金',
#   '云南省博士后科学基金',
#   '重庆市科学技术研究院',
#   '山西省卫生健康委员会',
#   '上海市卫生健康委员会',
#   '青海省卫生健康委员会',
#   '辽宁省卫生和计划生育委员会',
#   '广西壮族自治区人力资源和社会保障厅',
#   '福建省财政厅',
#   '福建省卫生计生委',
#   '甘肃省卫生健康委员会',
#   '贵州省卫生委员会',
#   '湖北省卫生健康委员会',
#   '河北省卫生健康委员会',
#   '海南省卫生和计划生育委员会',
#   '黑龙江省卫生健康委员会',
#   '江苏省卫生健康委员会',
#   '内蒙古自治区教育厅',
#   '天津市卫生健康委员会 承办单位',
#   '湖南省人力资源和社会保障厅',
#   'シスメックス株式会社',
#   '金沢大学自然環境工学研究所',
#   'डॉ। यशवंत सिंह परमार बागवानी और वानिकी विश्वविद्यालय',
#   'राष्ट्रसंत तुकडोजी महाराज नागपूर विद्यापीठ',
#   '日本新薬',
#   '日本新薬株式会社',
#   '日本化薬株式会社',
#   '笹川スポーツ財団',
#   'ίδρυμα thalassa',
#   'đại học y hà nội',
#   'গ্রিন ইউনিভার্সিটি অব বাংলাদেশ',
#   'उत्तर बंगाल विश्वविद्यालय',
#   'وكالة الأمم المتحدة لإغاثة وتشغيل اللاجئين الفلسطينيين',
#   '바이엘 코리아',
#   '公益財団法人 計算科学振興財団',
#   '日本心エコー図学会',
#   '公益財団法人京都技術科学センター',
#   '一般財団法人\u3000愛知健康増進財団',
#   '財団東洋食品研究所',
#   'シルフ協会',
#   '富士製薬工業',
#   '日本ゼオン',
#   '株式会社デンソ',
#   'キユーピー',
#   '清水建設株式会社',
#   '医療経済研究機構',
#   '公益財団法人 荏原 畠山記念文化財団',
#   'جامعة الحسين بن طلال',
#   'دانشگاه علوم کشاورزی و منابع طبیعی خوزستان',
#   'جامعة تكريت',
#   'มหาวิทยาลัยราชภัฏจันทรเกษม',
#   'εμπειρίκειον ίδρυμα',
#   '亚太森林恢复与可持续管理组织',
#   '公益財団法人 予防接種リサーチセンター',
#   '人工知能研究センター',
#   '日本心臓リハビリテーション学会',
#   '国立国語研究所',
#   '東京都中小企業振興公社は',
#   '東京都 産業労働局 中小企業振興公社',
#   '蒙特斯·克拉罗斯州立大学',
#   '芬美意',
#   'національний фонд досліджень україни',
#   'естественно-гуманитарный университет в г. седльце',
#   'கற்பகம் உயர்கல்வி அகாதெமி',
#   'भारतीय विश्वविद्यालयों का संघ',
#   '公益財団法人内視鏡医学研究振興財団',
#   'जीएलए विश्वविद्यालय',
#   'বিদ্যাসাগর বিশ্ববিদ্যালয়',
#   'àrainneachd eachdraidheil alba',
#   'एनआईटी श्रीनगर',
#   'राष्ट्रीय प्रौद्योगिकी संस्थान श्रीनगर',
#   'भारतीय सूचना प्रौद्योगिकी संस्थान, इलाहाबाद',
#   '명인 제약',
#   '5th district eagles cancer telethon',
#   '公益財団法人 新日本先進医療研究財団',
#   '香港安斯泰來製藥有限公司',
#   'ινστιτούτο χημικής βιολογίας',
#   '한국환경공단',
#   'サントリー生命科学財団',
#   'தமிழ்நாடு அறிவியல் தொழில்நுட்ப மாநில மன்றம்',
#   'त्रिभुवन विश्वविद्यालय',
#   'фонд поддержки прикладных экологических разработок и исследований',
#   'фонд озеро байкал',
#   '晨興基金會',
#   '輝瑞香港',
#   '札幌医科大学',
#   'γενική διεύθυνση ευρωπαϊκών προγραμμάτων, συντονισμού και ανάπτυξης',
#   'κυπριακή δημοκρατία, γενική διεύθυνση ευρωπαϊκών προγραμμάτων, συντονισμού και ανάπτυξης',
#   'γδ επσα',
#   '計算基礎科学連携拠点',
#   '明星大学',
#   '대한간호협회',
#   'ähtävänjoki foundation',
#   '一般財団法人\u3000大成学術財団',
#   'المعهد الفرنسي للآثار الشرقية',
#   '國家實驗動物中心',
#   '欧洲肿瘤研究所',
#   'европейский институт онкологии',
#   'المعهد الأوروبي للأورام',
#   '日本癌治療学会',
#   '滋賀県立大学',
#   '滋贺县立大学',
#   'សាកលវិទ្យាល័យ\u200bត្រាវិញ',
#   '日本歯科大学',
#   '神奈川県立産業技術総合研究所',
#   '東京都立広尾病院',
#   '东京都广尾医院',
#   '广州市妇女儿童医疗中心 儿科研究所',
#   '雙和醫院',
#   '衛生福利部雙和醫院',
#   '臺北醫學大學-雙和醫院，衛生福利部',
#   '金沢大学がん進展制御研究所',
#   'がん進展制御研究所',
#   '金沢大学',
#   '金大',
#   'ニプロの',
#   'ニプロ株式会社',
#   '日本医師会',
#   '公益社団法人 日本医師会 治験促進センター',
#   '株式会社コンポン研究所',
#   '“gheorghe asachi” technical university of iasi',
#   'иркутский национальный исследовательский технический университет',
#   'สำนักงานคณะกรรมการพิเศษเพื่อประสานงานโครงการอันเนื่องมาจากพระราชดำริ',
#   'สำนักงานคณะกรรมการโครงการอันเนื่องมาจากพระราชดำริ',
#   'สำนักงาน กปร.',
#   '대한 신경 학회',
#   'язанский государственный радиотехнический университет имени в.ф. уткина',
#   'рязанский государственный радиотехнический университет',
#   'đại học hàng hải việt nam',
#   '아모레퍼시픽',
#   '爱茉莉太平洋',
#   '科廷大学马来西亚分校',
#   '科廷大學馬來西亞分校',
#   'بجامعة يالوفا',
#   'πανεπιστήμιο μακεδονίας',
#   'πα.μακ',
#   'جامعة الحضارات اسطنبول',
#   'московский государственный психолого-педагогический университет',
#   'мгппу',
#   '一般社団法人 ja共済総合研究所',
#   '셀트리온',
#   'фонда луи бондюэля явл',
#   'фонда луи бондюэля',
#   '再生医療実現拠点ネットワークプログラム',
#   'มหาวิทยาลัยราชภัฎมหาสารคาม',
#   'トーアエイヨー',
#   '香港恒生大學',
#   '財団先端技術研究所',
#   'มหาวิทยาลัยราชภัฏ\u200bนครศรีธรรมราช',
#   'എ. പി. ജെ. അബ്ദുൽ കലാം ടെക്നോളജിക്കൽ യൂണിവേഴ്സിറ്റി',
#   '질병관리청',
#   '疾病管理廳',
#   '2nd second affiliated hospital of harbin medical university',
#   '哈尔滨医科大学附属第二医院',
#   '国防科技工业航空发动机创新中心',
#   '贵州师范学院',
#   '华北水利水电大学',
#   '山东农业工程学院',
#   '東京国際大学',
#   'دانشگاه علوم پزشکی تربت حیدریه',
#   '江苏恒瑞医药股份有限公司',
#   '恒瑞医药',
#   '蚂蚁集团',
#   '螞蟻集團',
#   '앤트그룹은',
#   'アントグループ',
#   '科研製薬株式会社',
#   '東ソー株式会社',
#   '川西記念新明和教育財団',
#   '长寿命高温材料国家重点实验室',
#   '한국뇌연구원',
#   'राष्ट्रीय प्रौद्योगिकी संस्थान सिक्किम',
#   'иркутский государственный университет',
#   'эрхүүгийн улсын их сургууль',
#   '伊尔库茨克国立大学',
#   '一般財団法人国土技術研究センター',
#   '公益財団法人 nec c&c財団',
#   '2. spins and heat in nanoscale electronic systems',
#   '建築研究所',
#   '中華民國內政部建築研究所',
#   '육아정책연구소',
#   '一般用医薬品セルフメディケーション振興財団',
#   '國立屏東科技大學',
#   '公益財団法人国際花と緑の博覧会',
#   '公益財団法人国際花と緑の博覧会記念協会',
#   'התאחדות מגדלי הבקר בישראל',
#   '羅鷹石慈慧基金',
#   'কৃষি গবেষণা ফাউন্ডেশন',
#   '愛知医科大学',
#   'राष्ट्रीय प्रौद्योगिकी संस्थान ,रायपुर',
#   '吴羽',
#   'たちクレハは',
#   '株式会社クレハ',
#   '复旦大学 脑科学前沿科学中心',
#   '孝感市科学技术局',
#   '北京市希思科临床肿瘤学研究基金会',
#   '安徽理工大学环境友好材料与职业健康研究院',
#   '湖南理工职业技术学院',
#   '中国工程物理研究院计算机应用研究所',
#   '江苏省气象局',
#   '昆明市卫生健康委员会',
#   '国家计算机网络应急技术处理协调中心',
#   '孝感市自然科学基金',
#   '浙江理工大学桐乡研究院',
#   '清华大学深圳国际研究生院',
#   '张家港市第一人民医院',
#   '上海汽车工业科技发展基金会',
#   '苏州市卫生健康委员会',
#   '河北北方学院',
#   '成都市社会科学界联合会',
#   '鹏城实验室',
#   '陕西省土地工程建设集团',
#   '陕西省土地工程建设集团有限责任公司',
#   '榆林市科学技术局',
#   '公益財団法人 永井科学技術財団',
#   '皖江工学院',
#   '长春工业大学',
#   '河南省卫生健康委员会',
#   '黑龙江省财政厅',
#   '丽水市科学技术局',
#   '西湖大学',
#   '中国科学院新疆理化技术研究所 新疆电子信息材料与器件重点实验室',
#   '枣庄市科学技术局',
#   '河南省人力资源和社会保障厅',
#   '淮安市科学技术局',
#   "诺丁汉大学'国际博士创新中心",
#   '辽宁省人力资源和社会保障厅',
#   '贺林院士新医学临床转化工作站科研基金',
#   '青岛市博士后科学基金',
#   '深圳市麦捷微电子科技股份有限公司',
#   '吉林省中医药管理局',
#   '中国建筑材料科学研究总院有限公司',
#   '中国建筑材料科学研究总院',
#   '广西中药质量标准重点实验室',
#   'भारतीय प्रौद्योगिकी संस्थान गांधीनगर',
#   '三菱ガス化学記念財団',
#   '浙江省城市环境过程与污染控制重点实验室',
#   '吉安市科学技术局',
#   '浮法玻璃新技术国家重点实验室',
#   '矿物加工科学与技术国家重点实验室',
#   '増屋記念基礎研究振興財団',
#   'đại học tôn đức thắng',
#   '7 aralık üniversitesi',
#   'ιδρύματος προποντίς',
#   'технически университет габрово',
#   'технически университет - габрово',
#   'जामिया मिलिया इस्लामिया',
#   'श्री चित्रा तिरुनाल आयुर्विज्ञान और प्रौद्योगिकी संस्थान, त्रिवेंद्रम',
#   'คณะเภสัชศาสตร์ มหาวิทยาลัยบูรพา',
#   '现将济南市哲学社会科学规划管理办公室',
#   '济南市哲学社科规划项目',
#   '江苏省哲学社会科学规划办公室',
#   '广州市社会科学规划领导小组办公室',
#   '广州市社科规划办',
#   '安徽省哲学社会科学规划办公室',
#   '安徽省社会科学规划项目',
#   '浙江省哲学社会科学办公室',
#   '河南省社科规划办公室',
#   '四川省哲学社会科学规划办公室',
#   '深圳市动力电池安全研究重点实验室',
#   '国联汽车动力电池研究院有限公司',
#   'συνδέσμου ελληνικών ακαδημαϊκών βιβλιοθηκών',
#   'σύνδεσμος ελληνικών ακαδημαϊκών βιβλιοθηκών',
#   'σεαβ',
#   'جمعية إشراق',
#   'معية السعودية لاضطراب فرط الحركة وتشتت الانتباه',
#   'ဆေးသုတေသနဦးစီးဌာန',
#   'קרן גנדיר',
#   '广东技术师范学院',
#   '广东科技学院',
#   '广西代谢病研究重点实验室',
#   '内蒙古科技大学',
#   '兰州城市学院',
#   '黔南民族师范学院',
#   '新余学院',
#   '浙江水利水电学院',
#   '台灣儀器科技研究中心',
#   '國研院儀科中心',
#   '國家實驗研究院台灣儀器科技研究中心',
#   'গ্লোবাল ইনভেস্টিগেটিভ জার্নালিজম নেটওয়ার্ক',
#   '全球深度报道网',
#   ...]}
